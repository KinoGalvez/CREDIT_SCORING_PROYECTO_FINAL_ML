# %% [markdown]
# LendingClub is a US peer-to-peer lending company, headquartered in San Francisco, California. It was the first peer-to-peer lender to register its offerings as securities with the Securities and Exchange Commission (SEC), and to offer loan trading on a secondary market. LendingClub is the world's largest peer-to-peer lending platform.

# %%
import pandas as pd
# 
# prueba github
# Cargar los archivos en DataFrames
lc = pd.read_csv('../data/raw/lending_club_loan_two.csv')
lc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 396030 entries, 0 to 396029
# Data columns (total 27 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   loan_amnt             396030 non-null  float64
#  1   term                  396030 non-null  object
#  2   int_rate              396030 non-null  float64
#  3   installment           396030 non-null  float64
#  4   grade                 396030 non-null  object
#  5   sub_grade             396030 non-null  object
#  6   emp_title             373103 non-null  object
#  7   emp_length            377729 non-null  object
#  8   home_ownership        396030 non-null  object
#  9   annual_inc            396030 non-null  float64
#  10  verification_status   396030 non-null  object
#  11  issue_d               396030 non-null  object
#  12  loan_status           396030 non-null  object
#  13  purpose               396030 non-null  object
# ...

# %%
pd.set_option('display.max_columns', None)
lc.head()
# Out:
#    loan_amnt        term  int_rate  installment grade sub_grade  \
# 0    10000.0   36 months     11.44       329.48     B        B4
# 1     8000.0   36 months     11.99       265.68     B        B5
# 2    15600.0   36 months     10.49       506.97     B        B3
# 3     7200.0   36 months      6.49       220.65     A        A2
# 4    24375.0   60 months     17.27       609.33     C        C5
#
#                  emp_title emp_length home_ownership  annual_inc  \
# 0                Marketing  10+ years           RENT    117000.0
# 1          Credit analyst     4 years       MORTGAGE     65000.0
# 2             Statistician   < 1 year           RENT     43057.0
# 3          Client Advocate    6 years           RENT     54000.0
# 4  Destiny Management Inc.    9 years       MORTGAGE     55000.0
#
#   verification_status   issue_d  loan_status             purpose  \
# 0        Not Verified  Jan-2015   Fully Paid            vacation
# ...

# %% [markdown]
# loan_amnt: Monto del préstamo solicitado.
# term: Plazo del préstamo en meses.
# int_rate: Tasa de interés del préstamo.
# installment: Pago mensual del préstamo.
# grade: Grado asignado al préstamo por LendingClub (A, B, C, etc.).
# sub_grade: Subgrado asignado al préstamo por LendingClub (A1, A2, B1, etc.).
# emp_title: Título laboral del prestatario.
# emp_length: Antigüedad laboral del prestatario en años.
# home_ownership: Estado de propiedad de la vivienda del prestatario (RENT, OWN, MORTGAGE, OTHER).
# annual_inc: Ingreso anual del prestatario.
# verification_status: Estado de verificación del ingreso del prestatario.
# issue_d: Fecha en la que se emitió el préstamo.
# loan_status: Estado actual del préstamo (Fully Paid, Charged Off, etc.).
# purpose: Propósito del préstamo.
# title: Título del préstamo proporcionado por el prestatario.
# dti: Relación entre las deudas y el ingreso del prestatario.
# earliest_cr_line: Fecha en que se abrió la primera línea de crédito del prestatario.
# open_acc: Número de líneas de crédito abiertas en el archivo del prestatario.
# pub_rec: Número de registros públicos desfavorables.
# revol_bal: Saldo total de las cuentas de crédito renovable.
# revol_util: Tasa de utilización de las cuentas de crédito renovable.
# total_acc: Número total de cuentas de crédito del prestatario.
# initial_list_status: Estado inicial de la lista del préstamo (W, F).
# application_type: Tipo de aplicación (INDIVIDUAL, JOINT).
# mort_acc: Número de cuentas hipotecarias.
# pub_rec_bankruptcies: Número de quiebras en los registros públicos.
# address: Dirección del prestatario.

# %%
lc.describe()
# Out:
#            loan_amnt       int_rate    installment    annual_inc  \
# count  396030.000000  396030.000000  396030.000000  3.960300e+05
# mean    14113.888089      13.639400     431.849698  7.420318e+04
# std      8357.441341       4.472157     250.727790  6.163762e+04
# min       500.000000       5.320000      16.080000  0.000000e+00
# 25%      8000.000000      10.490000     250.330000  4.500000e+04
# 50%     12000.000000      13.330000     375.430000  6.400000e+04
# 75%     20000.000000      16.490000     567.300000  9.000000e+04
# max     40000.000000      30.990000    1533.810000  8.706582e+06
#
#                  dti       open_acc        pub_rec     revol_bal  \
# count  396030.000000  396030.000000  396030.000000  3.960300e+05
# mean       17.379514      11.311153       0.178191  1.584454e+04
# std        18.019092       5.137649       0.530671  2.059184e+04
# min         0.000000       0.000000       0.000000  0.000000e+00
# ...

# %%
lc['issue_d'].dtype
# Out:
# dtype('O')

# %%
lc['issue_d'].max()
# Out:
# 'Sep-2016'

# %%
lc['issue_d'].min()
# Out:
# 'Apr-2008'

# %%
lc['loan_status'].unique()
# Out:
# array(['Fully Paid', 'Charged Off'], dtype=object)

# %%
lc['loan_status'].value_counts(normalize=True)
# Out:
# loan_status
# Fully Paid     0.803871
# Charged Off    0.196129
# Name: proportion, dtype: float64

# %%
# Cargar los archivos en DataFrames
lc_ac_2007_2018 = pd.read_csv('../data/raw/accepted_2007_to_2018Q4.csv')
lc_ac_2007_2018.head()
# Out:
# C:\Users\joaqu\AppData\Local\Temp\ipykernel_4572\2451777782.py:2: DtypeWarning: Columns (0,19,49,59,118,129,130,131,134,135,136,139,145,146,147) have mixed types. Specify dtype option on import or set low_memory=False.
#   lc_ac_2007_2018 = pd.read_csv('../data/raw/accepted_2007_to_2018Q4.csv')
#          id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0  68407277        NaN     3600.0       3600.0           3600.0   36 months
# 1  68355089        NaN    24700.0      24700.0          24700.0   36 months
# 2  68341763        NaN    20000.0      20000.0          20000.0   60 months
# 3  66310712        NaN    35000.0      35000.0          35000.0   60 months
# 4  68476807        NaN    10400.0      10400.0          10400.0   60 months
#
#    int_rate  installment grade sub_grade  ... hardship_payoff_balance_amount  \
# 0     13.99       123.03     C        C4  ...                            NaN
# ...

# %% [markdown]
# (0,19,49,59,118,129,130,131,134,135,136,139,145,146,147)
# 0...........id
# 19...........desc
# 49............fecha....next_pymnt_d
#
# 59..........verified not verified

# %%
# Obtener el índice de las columnas a eliminar
columnas_a_eliminar = [0, 19, 49, 59, 118, 129, 130, 131, 134, 135, 136, 139, 145, 146, 147]

# Eliminar las columnas por índice
lc_ac_2007_2018 = lc_ac_2007_2018.drop(lc_ac_2007_2018.columns[columnas_a_eliminar], axis=1)

# Alternativamente, puedes eliminar las columnas por nombre
# lc_ac_2007_2018 = lc_ac_2007_2018.drop(['Nombre_Columna1', 'Nombre_Columna2', ...], axis=1)

# Mostrar información del DataFrame después de la eliminación
print(lc_ac_2007_2018.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2260701 entries, 0 to 2260700
# Columns: 136 entries, member_id to settlement_term
# dtypes: float64(113), object(23)
# memory usage: 2.3+ GB
# None

# %%
lc_ac_2007_2018['loan_status'].isna().sum()
# Out:
# 33

# %%
lc_ac_2007_2018[(lc_ac_2007_2018['loan_status'] == 'Fully Paid') & (lc_ac_2007_2018['delinq_2yrs'] == 1)]
# Out:
#          member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 1              NaN    24700.0      24700.0          24700.0   36 months
# 4              NaN    10400.0      10400.0          10400.0   60 months
# 7              NaN    20000.0      20000.0          20000.0   36 months
# 24             NaN     6000.0       6000.0           6000.0   36 months
# 35             NaN     7000.0       7000.0           7000.0   36 months
# ...            ...        ...          ...              ...         ...
# 2260629        NaN    20000.0      20000.0          20000.0   60 months
# 2260649        NaN     5000.0       5000.0           5000.0   36 months
# 2260661        NaN    11200.0      11200.0          11200.0   60 months
# 2260663        NaN    30000.0      30000.0          30000.0   60 months
# 2260675        NaN    16000.0      16000.0          16000.0   60 months
#
#          int_rate  installment grade sub_grade                  emp_title  \
# ...

# %%
columna_en_posicion_19 = lc_ac_2007_2018.iloc[:, 16]

# Muestra todos los datos únicos en la columna en la posición 19
unique_values = columna_en_posicion_19.unique()

# Itera sobre los valores únicos e imprímelos
for value in unique_values:
    print(value)
# Out:
# n
# y
# nan

# %%
columna_en_posicion_19 = lc_ac_2007_2018.iloc[:, 59]

# Muestra todos los datos únicos en la columna en la posición 19
unique_values = columna_en_posicion_19.unique()

# Itera sobre los valores únicos e imprímelos
for value in unique_values:
    print(value)
# Out:
# 2.0
# 1.0
# 0.0
# 3.0
# 6.0
# 4.0
# 5.0
# 9.0
# 7.0
# 8.0
# 10.0
# 14.0
# 12.0
# nan
# 11.0
# 18.0
# 13.0
# 17.0
# 16.0
# 15.0

# %%
# lc_ac_2007_2018['desc'].nunique()

# %%
lc_ac_2007_2018.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2260701 entries, 0 to 2260700
# Columns: 136 entries, member_id to settlement_term
# dtypes: float64(113), object(23)
# memory usage: 2.3+ GB

# %% [markdown]
# id: Identificador único del préstamo asignado por LendingClub.
#
# member_id: Identificador único del miembro asignado por LendingClub.
#
# loan_amnt: Monto del préstamo solicitado.
#
# funded_amnt: Monto total del préstamo financiado.
#
# funded_amnt_inv: Monto total del préstamo comprometido por inversores.
#
# term: Plazo del préstamo en meses.
#
# int_rate: Tasa de interés del préstamo.
#
# installment: Pago mensual del préstamo.
#
# grade: Grado asignado al préstamo por LendingClub (A, B, C, etc.).
#
# sub_grade: Subgrado asignado al préstamo por LendingClub (A1, A2, B1, etc.).
#
# emp_title: Título laboral del prestatario.
#
# emp_length: Antigüedad laboral del prestatario en años.
#
# home_ownership: Estado de propiedad de la vivienda del prestatario (RENT, OWN, MORTGAGE, OTHER).
#
# annual_inc: Ingreso anual del prestatario.
#
# verification_status: Estado de verificación del ingreso del prestatario.
#
# issue_d: Fecha en la que se emitió el préstamo.
#
# loan_status: Estado actual del préstamo (Fully Paid, Charged Off, etc.).
#
# pymnt_plan: Indica si hay un plan de pago en curso.
#
# url: URL del préstamo en el sitio web de LendingClub.
#
# desc: Descripción del préstamo proporcionada por el prestatario.
#
# purpose: Propósito del préstamo.
#
# title: Título del préstamo proporcionado por el prestatario.
#
# zip_code: Los primeros 3 dígitos del código postal del prestatario.
#
# addr_state: Estado de residencia del prestatario.
#
# dti: Relación entre las deudas y el ingreso del prestatario.
#
# delinq_2yrs: Número de cuentas con pagos atrasados en los últimos 2 años.
#
# earliest_cr_line: Fecha en que se abrió la primera línea de crédito del prestatario.
#
# fico_range_low, fico_range_high: Rango FICO del prestatario.
#
# inq_last_6mths: Número de consultas de crédito en los últimos 6 meses.
#
# mths_since_last_delinq: Meses desde el último pago atrasado.
#
# mths_since_last_record: Meses desde el último registro público.
#
# open_acc: Número de líneas de crédito abiertas en el archivo del prestatario.
#
# pub_rec: Número de registros públicos desfavorables.
#
# revol_bal: Saldo total de las cuentas de crédito renovable.
#
# revol_util: Tasa de utilización de las cuentas de crédito renovable.
#
# total_acc: Número total de cuentas de crédito del prestatario.
#
# initial_list_status: Estado inicial de la lista del préstamo (W, F).
#
# out_prncp: Saldo pendiente de capital.
#
# out_prncp_inv: Saldo pendiente de capital para inversores.
#
# total_pymnt: Pago total recibido hasta la fecha.
#
# total_pymnt_inv: Pago total recibido hasta la fecha para inversores.
#
# total_rec_prncp: Total recibido como pago de capital.
#
# total_rec_int: Total recibido como pago de interés.
#
# total_rec_late_fee: Total recibido como tarifa por pago tardío.
#
# recoveries: Monto recuperado después de un cargo off.
#
# collection_recovery_fee: Tarifa de recuperación de colecciones.
#
# last_pymnt_d: Última fecha de pago.
#
# last_pymnt_amnt: Monto del último pago recibido.
#
# next_pymnt_d: Próxima fecha de pago programada.
#
# last_credit_pull_d: Última fecha en que se obtuvo una consulta de crédito.
#
# last_fico_range_high, last_fico_range_low: Rango FICO más reciente.
#
# collections_12_mths_ex_med: Número de colecciones en los últimos 12 meses excluyendo las médicas.
#
# mths_since_last_major_derog: Meses desde el último evento importante adverso.
#
# policy_code: Código de política de préstamo.
#
# application_type: Tipo de aplicación (INDIVIDUAL, JOINT).
#
# annual_inc_joint: Ingreso anual conjunto si la aplicación es conjunta.
#
# dti_joint: Relación deuda-ingreso conjunta si la aplicación es conjunta.
#
# verification_status_joint: Estado de verificación del ingreso conjunto.
#
# acc_now_delinq: Número de cuentas actualmente morosas.
#
# tot_coll_amt: Monto total de cuentas de colección.
#
# tot_cur_bal: Saldo total actual de todas las cuentas.
#
# open_acc_6m: Número de cuentas abiertas en los últimos 6 meses.
#
# open_act_il: Número de cuentas activas abiertas actualmente.
#
# open_il_12m: Número de cuentas de préstamos abiertas en los últimos 12 meses.
#
# open_il_24m: Número de cuentas de préstamos abiertas en los últimos 24 meses.
#
# mths_since_rcnt_il: Meses desde la apertura de la cuenta de préstamo más reciente.
#
# total_bal_il: Saldo total de todas las cuentas de préstamos.
#
# il_util: Tasa de utilización de cuentas de préstamos.
#
# open_rv_12m: Número de cuentas de crédito renovable abiertas en los últimos 12 meses.
#
# open_rv_24m: Número de cuentas de crédito renovable abiertas en los últimos 24 meses.
#
# max_bal_bc: Saldo máximo de la cuenta de crédito renovable.
#
# all_util: Tasa de utilización de todas las cuentas.
#
# total_rev_hi_lim: Límite alto total de crédito renovable.
#
# inq_fi: Número de instituciones financieras consultadas.
#
# total_cu_tl: Número total de líneas de crédito actuales.
#
# inq_last_12m: Número de consultas de crédito en los últimos 12 meses.
#
# acc_open_past_24mths: Número de cuentas abiertas en los últimos 24 meses.
#
# avg_cur_bal: Saldo promedio actual de todas las cuentas.
#
# bc_open_to_buy: Crédito disponible para comprar con tarjetas de crédito.
#
# bc_util: Utilización de crédito de tarjetas de crédito.
#
# chargeoff_within_12_mths: Número de cargos eliminados en los últimos 12 meses.
#
# delinq_amnt: Monto total de pagos atrasados.
#
# mo_sin_old_il_acct: Antigüedad de la cuenta de préstamo más antigua.
#
# mo_sin_old_rev_tl_op: Antigüedad de la cuenta de crédito renovable más antigua.
#
# mo_sin_rcnt_rev_tl_op: Meses desde la última cuenta de crédito renovable.
#
# mo_sin_rcnt_tl: Meses desde la última cuenta.
#
# mort_acc: Número de cuentas hipotecarias.
#
# mths_since_recent_bc: Meses desde la apertura de la cuenta de crédito renovable más reciente.
#
# mths_since_recent_bc_dlq: Meses desde el último incumplimiento en la cuenta de crédito renovable.
#
# mths_since_recent_inq: Meses desde la última consulta.
#
# mths_since_recent_revol_delinq: Meses desde el último incumplimiento de tarjeta de crédito renovable.
#
# num_accts_ever_120_pd: Número de cuentas con pagos atrasados de 120 días o más.
#
# num_actv_bc_tl: Número de cuentas activas de tarjetas de crédito.
#
# num_actv_rev_tl: Número de cuentas activas.
#
# num_bc_sats: Número de cuentas de tarjetas de crédito.
#
# num_bc_tl: Número de cuentas de tarjetas de crédito.
#
# num_il_tl: Número de cuentas de préstamos.
#
# num_op_rev_tl: Número de cuentas abiertas.
#
# num_rev_accts: Número total de cuentas de crédito.
#
# num_rev_tl_bal_gt_0: Número total de cuentas con saldo mayor que 0.
#
# num_sats: Número total de cuentas abiertas.
#
# num_tl_120dpd_2m: Número de cuentas con pagos atrasados de 120 días o más en los últimos 2 meses.
#
# num_tl_30dpd: Número de cuentas con pagos atrasados de 30 días o más.
#
# num_tl_90g_dpd_24m: Número de cuentas con pagos atrasados de 90 días o más en los últimos 24 meses.
#
# num_tl_op_past_12m: Número de cuentas abiertas en los últimos 12 meses.
#
# pct_tl_nvr_dlq: Porcentaje de cuentas nunca morosas.
#
# percent_bc_gt_75: Porcentaje de límite de crédito utilizado para saldos superiores al 75%.
#
# pub_rec_bankruptcies: Número de quiebras en los registros públicos.
#
# tax_liens: Número de gravámenes fiscales.
#
# tot_hi_cred_lim: Límite alto total de crédito.
#
# total_bal_ex_mort: Saldo total excluyendo hipotecas.
#
# total_bc_limit: Límite total de crédito bancario.
#
# total_il_high_credit_limit: Límite alto total de crédito de préstamos.
#
# revol_bal_joint: Saldo total de cuentas de crédito renovable conjunto.
#
# sec_app_fico_range_low, sec_app_fico_range_high: Rango FICO del co-solicitante.
#
# sec_app_earliest_cr_line: Fecha en que se abrió la primera línea de crédito del co-solicitante.
#
# sec_app_inq_last_6mths: Número de consultas de crédito en los últimos 6 meses del co-solicitante.
#
# sec_app_mort_acc: Número de cuentas hipotecarias del co-solicitante.
#
# sec_app_open_acc: Número de cuentas abiertas del co-solicitante.
#
# sec_app_revol_util: Tasa de utilización de cuentas de crédito renovable del co-solicitante.
#
# sec_app_open_act_il: Número de cuentas activas abiertas actualmente del co-solicitante.
#
# sec_app_num_rev_accts: Número total de cuentas de crédito del co-solicitante.
#
# sec_app_chargeoff_within_12_mths: Número de cargos eliminados en los últimos 12 meses del co-solicitante.
#
# sec_app_collections_12_mths_ex_med: Número de colecciones en los últimos 12 meses excluyendo las médicas del co-solicitante.
#
# sec_app_mths_since_last_major_derog: Meses desde el último evento importante adverso del co-solicitante.
#
# hardship_flag: Indica si hay dificultades económicas.
#
# hardship_type: Tipo de dificultad económica.
#
# hardship_reason: Razón de la dificultad económica.
#
# hardship_status: Estado de la dificultad económica.
#
# deferral_term: Término de diferimiento de pagos.
#
# hardship_amount: Monto de dificultad económica.
#
# hardship_start_date: Fecha de inicio de la dificultad económica.
#
#
# hardship_last_payment_amount: Monto del último pago de dificultades.
# disbursement_method: Método de desembolso.
# debt_settlement_flag: Indicador de arreglo de deuda.
# debt_settlement_flag_date: Fecha del indicador de arreglo de deuda.
# settlement_status: Estado del arreglo.
# settlement_date: Fecha del arreglo.
# settlement_amount: Monto del arreglo.
# settlement_percentage: Porcentaje del arreglo.
# settlement_term: Plazo del arreglo.

# %%
lc_ac_2007_2018.describe()
# Out:
#        member_id     loan_amnt   funded_amnt  funded_amnt_inv      int_rate  \
# count        0.0  2.260668e+06  2.260668e+06     2.260668e+06  2.260668e+06
# mean         NaN  1.504693e+04  1.504166e+04     1.502344e+04  1.309283e+01
# std          NaN  9.190245e+03  9.188413e+03     9.192332e+03  4.832138e+00
# min          NaN  5.000000e+02  5.000000e+02     0.000000e+00  5.310000e+00
# 25%          NaN  8.000000e+03  8.000000e+03     8.000000e+03  9.490000e+00
# 50%          NaN  1.290000e+04  1.287500e+04     1.280000e+04  1.262000e+01
# 75%          NaN  2.000000e+04  2.000000e+04     2.000000e+04  1.599000e+01
# max          NaN  4.000000e+04  4.000000e+04     4.000000e+04  3.099000e+01
#
#         installment    annual_inc           dti   delinq_2yrs  fico_range_low  \
# count  2.260668e+06  2.260664e+06  2.258957e+06  2.260639e+06    2.260668e+06
# mean   4.458068e+02  7.799243e+04  1.882420e+01  3.068792e-01    6.985882e+02
# ...

# %%
lc['issue_d'].dtype
# Out:
# dtype('O')

# %%
lc_ac_2007_2018['issue_d'] = pd.to_datetime(lc_ac_2007_2018['issue_d'], format='%b-%Y')

# Filtrar el DataFrame para las fechas específicas
df_filtrado = lc_ac_2007_2018[(lc_ac_2007_2018['issue_d'] >= '2008-04-01') & (lc_ac_2007_2018['issue_d'] <= '2016-09-30')]

# %%
df_filtrado.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1216685 entries, 0 to 2038500
# Columns: 136 entries, member_id to settlement_term
# dtypes: datetime64[ns](1), float64(113), object(22)
# memory usage: 1.2+ GB

# %%
df_filtrado.describe()
# Out:
#        member_id     loan_amnt   funded_amnt  funded_amnt_inv      int_rate  \
# count        0.0  1.216685e+06  1.216685e+06     1.216685e+06  1.216685e+06
# mean         NaN  1.480626e+04  1.479666e+04     1.477456e+04  1.313938e+01
# min          NaN  5.000000e+02  5.000000e+02     0.000000e+00  5.320000e+00
# 25%          NaN  8.000000e+03  8.000000e+03     8.000000e+03  9.750000e+00
# 50%          NaN  1.300000e+04  1.300000e+04     1.300000e+04  1.279000e+01
# 75%          NaN  2.000000e+04  2.000000e+04     2.000000e+04  1.580000e+01
# max          NaN  4.000000e+04  4.000000e+04     4.000000e+04  3.099000e+01
# std          NaN  8.568262e+03  8.564308e+03     8.566473e+03  4.535909e+00
#
#         installment    annual_inc                        issue_d  \
# count  1.216685e+06  1.216685e+06                        1216685
# mean   4.397602e+02  7.615012e+04  2015-01-07 03:34:06.894635520
# min    4.930000e+00  0.000000e+00            2008-04-01 00:00:00
# ...

# %%
columnas_a_mantener = ['int_rate', 'installment', 'grade']



# Mantener las columnas en df1 y agregar las columnas únicas de df2
df2_sin_coincidencias = df_filtrado[columnas_a_mantener + [col for col in df_filtrado.columns if col not in lc.columns]]



df2_sin_coincidencias.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1216685 entries, 0 to 2038500
# Columns: 113 entries, int_rate to settlement_term
# dtypes: float64(103), object(10)
# memory usage: 1.0+ GB

# %%
# Seleccionar las columnas de tipo float64 y cambiar a float32
lc[lc.select_dtypes(include=['float64']).columns] = lc.select_dtypes(include=['float64']).astype('float32')

lc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 396030 entries, 0 to 396029
# Data columns (total 27 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   loan_amnt             396030 non-null  float32
#  1   term                  396030 non-null  object
#  2   int_rate              396030 non-null  float32
#  3   installment           396030 non-null  float32
#  4   grade                 396030 non-null  object
#  5   sub_grade             396030 non-null  object
#  6   emp_title             373103 non-null  object
#  7   emp_length            377729 non-null  object
#  8   home_ownership        396030 non-null  object
#  9   annual_inc            396030 non-null  float32
#  10  verification_status   396030 non-null  object
#  11  issue_d               396030 non-null  object
#  12  loan_status           396030 non-null  object
#  13  purpose               396030 non-null  object
# ...

# %%
# float64_columns = df2_sin_coincidencias.select_dtypes(include=['float64']).columns
# df2_sin_coincidencias.loc[:, float64_columns] = df2_sin_coincidencias.loc[:, float64_columns].astype('float32')

# df2_sin_coincidencias.info()
df2_sin_coincidencias[df2_sin_coincidencias.select_dtypes(include=['float64']).columns] = df2_sin_coincidencias.select_dtypes(include=['float64']).astype('float32')
df2_sin_coincidencias.info()
# Out:
# C:\Users\joaqu\AppData\Local\Temp\ipykernel_9740\3719192964.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2_sin_coincidencias[df2_sin_coincidencias.select_dtypes(include=['float64']).columns] = df2_sin_coincidencias.select_dtypes(include=['float64']).astype('float32')
# <class 'pandas.core.frame.DataFrame'>
# Index: 1216685 entries, 0 to 2038500
# Columns: 113 entries, int_rate to settlement_term
# dtypes: float32(103), object(10)
# memory usage: 580.2+ MB

# %%
df2_sin_coincidencias
# Out:
#           int_rate  installment grade  member_id  funded_amnt  \
# 0        13.990000   123.029999     C        NaN       3600.0
# 1        11.990000   820.280029     C        NaN      24700.0
# 2        10.780000   432.660004     B        NaN      20000.0
# 3        14.850000   829.900024     C        NaN      35000.0
# 4        22.450001   289.910004     F        NaN      10400.0
# ...            ...          ...   ...        ...          ...
# 2038496   7.390000   155.279999     A        NaN       5000.0
# 2038497  10.750000    68.510002     B        NaN       2100.0
# 2038498  10.490000   687.650024     B        NaN      32000.0
# 2038499  14.490000    55.070000     C        NaN       1600.0
# 2038500   7.890000   687.609985     A        NaN      34000.0
#
#          funded_amnt_inv pymnt_plan  \
# 0                 3600.0          n
# 1                24700.0          n
# 2                20000.0          n
# 3                35000.0          n
# ...

# %% [markdown]
# int_rate	installment	grade	id	member_id	funded_amnt	funded_amnt_inv	pymnt_plan	url	desc	zip_code	addr_state	delinq_2yrs	fico_range_low	fico_range_high	inq_last_6mths	mths_since_last_delinq	mths_since_last_record	out_prncp	out_prncp_inv	total_pymnt	total_pymnt_inv	total_rec_prncp	total_rec_int	total_rec_late_fee	recoveries	collection_recovery_fee	last_pymnt_d	last_pymnt_amnt	next_pymnt_d	last_credit_pull_d	last_fico_range_high	last_fico_range_low	collections_12_mths_ex_med	mths_since_last_major_derog	policy_code	annual_inc_joint	dti_joint	verification_status_joint	acc_now_delinq	tot_coll_amt	tot_cur_bal	open_acc_6m	open_act_il	open_il_12m	open_il_24m	mths_since_rcnt_il	total_bal_il	il_util	open_rv_12m	open_rv_24m	max_bal_bc	all_util	total_rev_hi_lim	inq_fi	total_cu_tl	inq_last_12m	acc_open_past_24mths	avg_cur_bal	bc_open_to_buy	bc_util	chargeoff_within_12_mths	delinq_amnt	mo_sin_old_il_acct	mo_sin_old_rev_tl_op	mo_sin_rcnt_rev_tl_op	mo_sin_rcnt_tl	mths_since_recent_bc	mths_since_recent_bc_dlq	mths_since_recent_inq	mths_since_recent_revol_delinq	num_accts_ever_120_pd	num_actv_bc_tl	num_actv_rev_tl	num_bc_sats	num_bc_tl	num_il_tl	num_op_rev_tl	num_rev_accts	num_rev_tl_bal_gt_0	num_sats	num_tl_120dpd_2m	num_tl_30dpd	num_tl_90g_dpd_24m	num_tl_op_past_12m	pct_tl_nvr_dlq	percent_bc_gt_75	tax_liens	tot_hi_cred_lim	total_bal_ex_mort	total_bc_limit	total_il_high_credit_limit	revol_bal_joint	sec_app_fico_range_low	sec_app_fico_range_high	sec_app_earliest_cr_line	sec_app_inq_last_6mths	sec_app_mort_acc	sec_app_open_acc	sec_app_revol_util	sec_app_open_act_il	sec_app_num_rev_accts	sec_app_chargeoff_within_12_mths	sec_app_collections_12_mths_ex_med	sec_app_mths_since_last_major_derog	hardship_flag	hardship_type	hardship_reason	hardship_status	deferral_term	hardship_amount	hardship_start_date	hardship_end_date	payment_plan_start_date	hardship_length	hardship_dpd	hardship_loan_status	orig_projected_additional_accrued_interest	hardship_payoff_balance_amount	hardship_last_payment_amount	disbursement_method	debt_settlement_flag	debt_settlement_flag_date	settlement_status	settlement_date	settlement_amount	settlement_percentage	settlement_term

# %%
columnas_a_eliminar = ['member_id', 'url', 'zip_code', 'addr_state']

# Eliminar las columnas por partes
for col in columnas_a_eliminar:
    df2_sin_coincidencias = df2_sin_coincidencias.drop(columns=[col])

# %%
# Obtener una muestra del primer DataFrame
lc_sample = lc.sample(frac=0.1)  # Ajusta el tamaño de la muestra según sea necesario

# Fusionar con el segundo DataFrame
merged_df = pd.merge(lc_sample, df2_sin_coincidencias, on=['int_rate', 'installment'], how='inner', suffixes=('_df1', '_df2'))

# %%
# # Fusiona los DataFrames en función de las columnas 'A' y 'B'
# merged_df = pd.merge(lc, df2_sin_coincidencias, on=['int_rate', 'installment', 'grade'], how='inner', suffixes=('_df1', '_df2'))

# # Mostrar el DataFrame fusionado
# merged_df
